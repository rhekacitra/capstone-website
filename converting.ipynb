# %%
from nilearn import plotting

view = plotting.view_img(
    "thresh_zstat1.nii.gz",
    bg_img="MNI152_T1_1mm_brain.nii.gz",
    threshold=2.3,
    vmin=0,
    vmax=36.6,
    cmap="hot",
    black_bg=False,
    symmetric_cmap=False,
)


view.save_as_html("brain_view_sentences_AVH+.html")
